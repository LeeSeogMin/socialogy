# %% [markdown]
# # W10. 질문부터 해석까지 혼자 완주할 수 있는가? — 개인 미니 완주
#
# > 1-8주에서 배운 분석 흐름을 처음부터 끝까지 혼자 수행하여, 1쪽 요약 메모를 완성할 수 있는가?
#
# **학습 목표**
# 1. 연구 질문 → 변수 정의 → 기술통계 → 검정 선택 → 가정 확인 → 실행 → 해석문의 **전 과정을 독립적으로 수행**할 수 있다.
# 2. 분석 결과를 사회과학 글쓰기 구조(서론 → 방법 → 결과 → 논의)에 맞추어 **1쪽 요약 메모**로 정리할 수 있다.
# 3. 자신의 분석 과정을 되돌아보며, **한계와 개선점**을 식별할 수 있다.

# %%
# 크로스플랫폼 한글 폰트 설정 (macOS / Windows)
import platform
import matplotlib.pyplot as plt

if platform.system() == "Darwin":  # macOS
    plt.rcParams["font.family"] = "AppleGothic"
elif platform.system() == "Windows":
    plt.rcParams["font.family"] = "Malgun Gothic"
plt.rcParams["axes.unicode_minus"] = False

# %% [markdown]
# ## A회차: 분석 흐름 완주 안내
#
# ### 이번 주의 위치
#
# - **1-8주차 학습 내용 정리**:
#
# | 주차 | 핵심 기법 |
# |---:|---|
# | 2주 | 데이터 리터러시, 정제 |
# | 3주 | 기술통계, 분포, 산포 |
# | 4주 | 분할표, 카이자승 검정 |
# | 5주 | 가설검정 논리 |
# | 6주 | t-검정, ANOVA |
# | 7주 | 단순회귀 |
# | 8주 | 중다회귀 |
#
# - **이번 주 특징**: 새로운 개념 **없음**
# - **목표**: 위 기법을 연구 질문 하나에 **통합 적용**
# - **수행 방식**: 교수 제시 연구 질문 2-3개 중 1개 선택 → 전 과정 **스스로 수행**

# %% [markdown]
# ---
#
# ### 분석 흐름 완주 체크리스트
#
# - 모든 분석은 아래 7단계를 따른다. 과제 수행 시 이 체크리스트를 순서대로 점검한다.
#
# | 단계 | 내용 | 확인 |
# |---:|---|---|
# | 1 | **연구 질문** 설정 (1문장) | [ ] |
# | 2 | **변수 정의**: 독립/종속 변수, 척도(명목/서열/등간·비율) 명시 | [ ] |
# | 3 | **기술통계**: 빈도표, 평균/표준편차, 히스토그램 등으로 데이터 탐색 | [ ] |
# | 4 | **검정 선택**: 변수 유형과 질문에 맞는 분석 기법 선택 (아래 표 참고) | [ ] |
# | 5 | **가정 확인**: 선택한 검정의 전제 조건 충족 여부 확인 | [ ] |
# | 6 | **검정 실행**: 코드 실행 및 결과 확인 | [ ] |
# | 7 | **해석문 작성**: 4단계 해석문 (분석목적 → 핵심근거 → 결론 → 주의/한계) | [ ] |

# %% [markdown]
# ---
#
# ### 검정 선택 가이드
#
# | 독립변수 | 종속변수 | 추천 기법 |
# |---|---|---|
# | 범주형 (2수준) | 범주형 | 카이자승 검정 |
# | 범주형 (2수준) | 연속형 | 독립표본 t-검정 |
# | 범주형 (3수준+) | 연속형 | 일원분산분석(ANOVA) |
# | 연속형 | 연속형 | 단순회귀/중다회귀 |

# %% [markdown]
# ---
#
# ### 1쪽 요약 메모 구조
#
# - **최종 제출물**: 아래 구조의 1쪽 요약 메모
# - **특징**: 사회과학 글쓰기의 기본 구조 따름
#
# 1. **서론** (2-3문장)
#    - 연구 질문
#    - 그 질문이 왜 중요한지
#
# 2. **방법** (3-4문장)
#    - 사용 데이터
#    - 변수(척도 포함)
#    - 분석 기법
#    - 가정 확인 결과
#
# 3. **결과** (3-4문장)
#    - 핵심 수치(검정통계량, p값, 효과크기 등)
#    - 표/그래프 1개
#
# 4. **논의** (2-3문장)
#    - 결론
#    - 한계
#    - "이 분석이 말할 수 없는 것"

# %% [markdown]
# ## B회차: 개인 미니 종합 — 과제 9
#
# ### 과제 안내
#
# | 항목 | 내용 |
# |---|---|
# | 과제 유형 | **개인 과제** (조별 아님) |
# | 소요 시간 | 40분 |
# | 제출 형식 | A-E 형식 + 1쪽 요약 메모 |
# | 제출처 | Google Classroom |

# %% [markdown]
# ---
#
# ### 기본(Basic) / 확장(Plus) 트랙
#
# | 트랙 | 내용 |
# |---|---|
# | **기본** (필수) | 교수 제시 질문 1개를 분석하고, A-E + 1쪽 요약 메모 제출 |
# | **확장** (가산점) | 본인이 직접 설정한 연구 질문으로 추가 분석 1건 수행 |

# %% [markdown]
# ---
#
# ### 흔한 오류 3가지
#
# | 오류 | 확인법 |
# |---|---|
# | 변수 척도를 잘못 판단하여 부적절한 검정 선택 | 검정 선택 가이드 표 다시 확인 |
# | 가정 확인 생략하고 바로 검정 실행 | 체크리스트 5단계 반드시 거치기 |
# | 해석문에서 "인과" 주장 | "관련이 있다/차이가 있다"로 표현, "~때문이다"는 사용 금지 |
